# %% [markdown]
# <a href="https://colab.research.google.com/github/stupidbutsmart/DELE-CA1/blob/master/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style>
#   b {
#     color: red;
#   }
# </style>

# %% [markdown]
# ## Section A CA1 CNN
#
# Name: Jovan Heng Ghim Hong
#
# Class: DAAA/2B/22
#
# Admin No: 2401418

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# Basic Imports
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import pickle
import gc
import warnings

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten ,Conv2D, MaxPooling2D , UpSampling2D, Cropping2D, ReLU, BatchNormalization, Dropout, LeakyReLU, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.regularizers import l1 , l2
from tensorflow.keras.metrics import Precision , Recall
from sklearn.model_selection import RandomizedSearchCV,ParameterGrid, train_test_split
from sklearn.metrics import classification_report, ConfusionMatrixDisplay, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Creating UDFs to aid workflow
#
# Before i start, i want to create some functions that can help me with my work.
#
# basic functions like:
# 1. create model function
# 2. autoencoder function
# 3. data processing functions
#
# etc.
#
# This can help modularize my code (especially since im working with 2 models) and make it easier for future collaborater to understand

# %%
DATASET_PATH = './datasets/'
STORED_DATA ='./stored_data/'
def get_greyscale_data(data_type , size):
  targets = [ target for target in os.listdir(DATASET_PATH + data_type)]

  rows = []
  for target in targets: 
    for file_name in os.listdir(os.path.join(DATASET_PATH , data_type ,  target)):
      # greyscale 
      img = image.load_img(os.path.join(DATASET_PATH , data_type, target , file_name ) ,color_mode='grayscale' , target_size=size)
      img = image.img_to_array(img) / 255.0 # divide by 255 to normalize it
      
      record = {'sequence' : img}
      for t in targets:
        record[t] = 1 if t == target else 0

      rows.append(record)

  return pd.DataFrame(rows , columns=['sequence'] + targets)

# %% [markdown]
# ### Data Cleaning and Exploration

# %% [markdown]
# I plan to do manual inspection to clean my data, therfore cleaning will be done before importing

# %% [markdown]
# ##### What i Found
#
# 1. There are some **duplicated images**, we will remove using **.drop_duplicates()** when we eventually import it
#
# ##### Test:
#
# 1. **Pumpkin** Folder Contains only **Tomatoes**
# 2. **Tomato** Folder Contains only **Pumpkins**
# 3. The folders are misnamed. For example **Bottle_Gourd and Cucumbers** should be **Cucumbers and Bottle Gourd**
#
# So i just changed the names of those folders
#
# ##### Train:
#
# 1. **Beans** Contains some **Carrots**
#
# I will move them into the **carrots** folder, incase of duplicates, they will be dropped later.
#
# ##### Validation:
#
# Looks about as clean as it can get

# %%
## NOTE
## get_greyscale_data() takes awhile to run
## below there is a function that builds the DF from ./stored_data
## run if ./stored_data was not provided, otherwise run cell with build_data() below
train_data_23 = get_greyscale_data('train' , (23 , 23))
## repeat for test and validation
test_data_23 = get_greyscale_data('test' , (23 , 23))
validation_data_23 = get_greyscale_data('validation' , (23 , 23))

# 101
train_data_101 = get_greyscale_data('train' , (101 , 101))
test_data_101 = get_greyscale_data('test' , (101 , 101))
validation_data_101 = get_greyscale_data('validation' , (101 , 101))

# %%
# Removing Duplicates
def remove_dupes(data):
  # Since we cannot hash lists, we need a string equivalent
  # This allows me to use the drop_duplicate function
  data['sequence_str'] = data['sequence'].apply(lambda x: str(x))
  data = data.drop_duplicates(subset=[col for col in data.columns if col != 'sequence'])
  data = data.drop(columns=['sequence_str'])
  return data

# %%
test_data_23 = remove_dupes(test_data_23)
train_data_23 = remove_dupes(train_data_23)
validation_data_23 = remove_dupes(validation_data_23)

test_data_101 = remove_dupes(test_data_101)
train_data_101 = remove_dupes(train_data_101)
validation_data_101 = remove_dupes(validation_data_101)

# %% [markdown]
# In order to save computional time, we will save the data, allowing us to build our df from it.
#
# We are using json format, as integrates seamlessly with my **sequence** column

# %%
#23 
train_data_23.to_json(os.path.join(STORED_DATA , 'train_23.json') , orient='records')
test_data_23.to_json(os.path.join(STORED_DATA , 'test_23.json') , orient='records')
validation_data_23.to_json(os.path.join(STORED_DATA , 'validation_23.json') , orient='records')
#101
train_data_101.to_json(os.path.join(STORED_DATA , 'train_101.json') , orient='records')
test_data_101.to_json(os.path.join(STORED_DATA , 'test_101.json') , orient='records')
validation_data_101.to_json(os.path.join(STORED_DATA , 'validation_101.json') , orient='records')

# %% [markdown]
# With our data exported, we can reimport it

# %%
# 23
train_data_23 = pd.read_json(os.path.join(STORED_DATA , 'train_23.json'))
test_data_23 = pd.read_json(os.path.join(STORED_DATA , 'test_23.json'))
validation_data_23 = pd.read_json(os.path.join(STORED_DATA , 'validation_23.json'))

# %%
# 101
train_data_101 = pd.read_json(os.path.join(STORED_DATA , 'train_101.json'))
test_data_101 = pd.read_json(os.path.join(STORED_DATA , 'test_101.json'))
validation_data_101 = pd.read_json(os.path.join(STORED_DATA , 'validation_101.json'))

# %% [markdown]
# We can recontruct it and plot it using matplotlib

# %%
fig , ax = plt.subplots(1 , 2, figsize=(16 , 6))
ax[0].imshow(train_data_23['sequence'].iloc[0] , cmap='gray')
ax[0].axis('off')
ax[1].imshow(train_data_101['sequence'].iloc[0] , cmap='gray')
ax[1].axis('off')
plt.show()

# %% [markdown]
# ##### Comparing it to its real img counterpart
# <style>
# .two_col_row {
#   display: grid;
#   grid-template-columns: 1fr 1fr; /* Two equal columns */
#   gap: 20px; /* Space between items */
#   padding: 20px
# }
#
# img {
#   height: auto;
#   width: 100%;
# }
#
#
#
#   </style>
# <div class='two_col_row'>
#   <img src='./markdown/bean_1_imap.png'>
#   <img src='./markdown/bean_1_original.jpg'>
# </div>
#
#
# looks like a very nice bean

# %%
# Comparing classes
# Both classes are the same for 23 and 101 datasets

counts = []
for col in train_data_23.columns[1:]:
  amount_of_class = train_data_23[col].value_counts()[1]
  counts.append(amount_of_class)

plt.figure(figsize=(8 , 8))
plt.pie(counts, labels=train_data_23.columns[1:], autopct='%1.1f%%', shadow=True, colors=plt.cm.Set3.colors[:11])
plt.title('Proportion of classes in train data')
plt.show()

# %%
counts = []
for col in test_data_23.columns[1:]:
  amount_of_class = test_data_23[col].value_counts()[1]
  counts.append(amount_of_class)

plt.figure(figsize=(8 , 8))
plt.pie(counts, labels=test_data_23.columns[1:], autopct='%1.1f%%', shadow=True, colors=plt.cm.Set3.colors[:11])
plt.title('Proportion of classes in test data')
plt.show()

# %%
counts = []
for col in validation_data_23.columns[1:]:
  amount_of_class = validation_data_23[col].value_counts()[1]
  counts.append(amount_of_class)

plt.figure(figsize=(8 , 8))
plt.pie(counts, labels=validation_data_23.columns[1:], autopct='%1.1f%%', shadow=True, colors=plt.cm.Set3.colors[:11])
plt.title('Proportion of classes in validation data')
plt.show()

# %% [markdown]
# This shows that the train data has **unbalanced features** while the test and validation is **perfectly balanced**
#
#
# This suggests that i should use metrics like recall when training
#
# I can also attempt to use class weights when training to balance out the imbalanced data
#
# ##### Metrics
#
# Due to the class imbalances, it is still a good idea to use a different metric from accuracy.
#
# **Why?**
#
# Even with the class weights, the model might still learn to **prioritize the smaller classes** to minimize loss.
#
#
# I will use **recall** to monitor my performance, but it is still important to look at the recall for each class instead of overall.
#
# This will be the main area of focus for my cnn

# %%
# 23
X_train_23 = np.asarray(np.stack(train_data_23['sequence']) , dtype=np.float32)
y_train_23 = np.asarray(train_data_23.drop(columns=['sequence']).values.astype(float), dtype=np.float32)

X_test_23 = np.stack(test_data_23['sequence'])
y_test_23 = test_data_23.drop(columns=['sequence']).values

X_validation_23 = np.asarray(np.stack(validation_data_23['sequence']), dtype=np.float32)
y_validation_23 = np.asarray(validation_data_23.drop(columns=['sequence']).values.astype(float) , dtype = np.float32)


# 101
X_train_101 = np.asarray(np.stack(train_data_101['sequence']) , dtype=np.float32)
y_train_101 = np.asarray(train_data_101.drop(columns=['sequence']).values.astype(float), dtype=np.float32)

X_test_101 = np.stack(test_data_101['sequence'])
y_test_101 = test_data_101.drop(columns=['sequence']).values

X_validation_101 = np.asarray(np.stack(validation_data_101['sequence']), dtype=np.float32)
y_validation_101 = np.asarray(validation_data_101.drop(columns=['sequence']).values.astype(float) , dtype = np.float32)

# %%
## Generating class weights
## These labels can be used for both sizes
# used only before data aug

y_train_labels = np.argmax(y_train_23, axis=1)
class_labels = np.unique(y_train_labels)
class_weights = compute_class_weight(
  class_weight='balanced', 
  classes=class_labels,
  y=y_train_labels 
)

class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# ##### Is my data enough?
#
# One easy way to check if to create a very simple and generic model. We can also use this as our **baseline model**
#
# We can train the data on the baseline model and **compare the val and train f1 scores**
#
# **Ideally** we should see both the train and the val flatline

# %%
def create_baseline_model():
  baseline_model = Sequential([
    Conv2D(32, kernel_size=(5 , 5), padding='same'),
    BatchNormalization(),
    ReLU(), 
    MaxPooling2D((3 , 3), padding='same'),
    
    Conv2D(64, kernel_size=(5 , 5), padding='same'),
    BatchNormalization(),
    ReLU(), 
    MaxPooling2D((3 , 3), padding='same'),
    
    Conv2D(128, kernel_size=(5 , 5), padding='same'),
    BatchNormalization(),
    ReLU(), 
    MaxPooling2D((3 , 3), padding='same'),

    Dropout(0.7),
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(11 , activation='softmax')
  ])

  baseline_model.compile(loss='categorical_crossentropy' , optimizer=Adam(learning_rate=0.0001), metrics=[
    Precision(name='precision'), Recall(name='recall'), 'accuracy'
  ])
  return baseline_model

# %%
# Training on splits in order to see if the f1 score plateaus 
splits = [0.25, 0.5 , 0.75 , 1] 

fig , ax = plt.subplots(1 , 2 , figsize=(16 , 6))

for i in range(2):
  last_4_val_recall = []
  last_4_recall = []
  for split in splits:
    print(f'Training on {split} of data size {23 if i == 0 else 101}')

    # data handling
    if i == 0: # 23
      if split != 1:
        X_train_split , _ ,y_train_split , _ = train_test_split(X_train_23 , y_train_23, random_state=42 , train_size=split , stratify=y_train_23)
        X_train_split = np.asarray(X_train_split, dtype=np.float32)
        y_train_split = np.asarray(y_train_split, dtype=np.float32)
      else:
        X_train_split = np.asarray(X_train_23, dtype=np.float32)
        y_train_split = np.asarray(y_train_23, dtype=np.float32)

      X_validation = np.asarray(X_validation_23, dtype=np.float32)
      y_validation = np.asarray(y_validation_23, dtype=np.float32)
    else: # 101
      if split != 1:
        X_train_split , _ ,y_train_split , _ = train_test_split(X_train_101 , y_train_101, random_state=42 , train_size=split , stratify=y_train_101)
        X_train_split = np.asarray(X_train_split, dtype=np.float32)
        y_train_split = np.asarray(y_train_split, dtype=np.float32)
      else:
        X_train_split = np.asarray(X_train_101, dtype=np.float32)
        y_train_split = np.asarray(y_train_101, dtype=np.float32)

      X_validation = np.asarray(X_validation_101, dtype=np.float32)
      y_validation = np.asarray(y_validation_101, dtype=np.float32)
      

    early_stop = EarlyStopping(patience=5, monitor='val_recall' ,restore_best_weights=True , mode='max') 
    baseline_model = create_baseline_model()

    # # if have model load it and run
    # if os.path.exists(os.path.join('stored_models' , 'baseline_model' , f'baseline_model_{23 if i == 0 else 101}_{split}.h5')):
    #   baseline_model.load_weights(os.path.join('stored_models' , 'baseline_model' , f'baseline_model_{23 if i == 0 else 101}_{split}.h5'))
    #   val_recall = baseline_model.evaluate(X_validation, y_validation, return_dict=True)['recall']
    #   train_recall = baseline_model.evaluate(X_train_split , y_train_split, return_dict=True)['recall']

    #   last_4_val_recall.append(val_recall)      
    #   last_4_recall.append(train_recall)
      

    # else:
    base_model_fit_results = baseline_model.fit(X_train_split, y_train_split,
                       epochs=200,
                       batch_size=32,
                       validation_data=(X_validation , y_validation),
                       verbose=0,
                       class_weight=class_weights_dict,
                       callbacks=[early_stop]
    )

    last_4_val_recall.append(np.max(base_model_fit_results.history['val_recall']))
    last_4_recall.append(np.max(base_model_fit_results.history['recall']))

    ## Store it for better reproducability
    # baseline_model.save_weights(os.path.join('stored_models' , 'baseline_model' , f'baseline_model_{23 if i == 0 else 101}_{split}.h5'))
  # Plotting
  ax[i].plot(splits , last_4_val_recall, label='validation')
  ax[i].plot(splits , last_4_recall , label='training')
  ax[i].set_title(f'recall against data splits {23 if i == 0 else 101}')
  ax[i].set_xlabel('splits')
  ax[i].set_ylabel('recall')
  ax[i].legend()
  ax[i].set_xticks(splits)
    
plt.show()
# Out:
# Training on 0.25 of data size 23
# Training on 0.5 of data size 23
# Training on 0.75 of data size 23
# Training on 1 of data size 23
# Training on 0.25 of data size 101
# Training on 0.5 of data size 101
# Training on 0.75 of data size 101
# Training on 1 of data size 101

# %% [markdown]
# It quite clearly shows that the validation and train data can still increase together. (their lines are not parallel)
#
# However it does seem like their performance is about to peak already, suggesting maybe a small increase (0.2) should be enough for it.

# %%
datagen = ImageDataGenerator(
    rotation_range=0,
    width_shift_range=0,
    height_shift_range=0,
    zoom_range=[0.8 , 1.2],
    horizontal_flip=False,
    fill_mode='nearest'
)

# %%
X_23 = np.stack(train_data_23["sequence"].values)  
y_23 = np.stack(train_data_23.drop(columns=['sequence']).values)

# %%
augment_size = int(0.2 * len(X_23))

X_aug = np.zeros((augment_size,) + X_23.shape[1:])
y_aug = np.zeros((augment_size,) + y_23.shape[1:])

for i in range(augment_size):
    # Get a random index
    idx = np.random.randint(0, len(X_23))
    img = X_23[idx].reshape((1,) + X_23[idx].shape)
    aug_img = next(datagen.flow(img, batch_size=1))[0]
    X_aug[i] = aug_img
    y_aug[i] = y_23[idx]

# Combining the data
X_train_23_augmented = np.concatenate([X_23, X_aug])
y_train_23_augmented = np.concatenate([y_23, y_aug])

X_train_23_augmented = np.asarray(X_train_23_augmented, dtype=np.float32)
y_train_23_augmented = np.asarray(y_train_23_augmented, dtype=np.float32)

# %%
# Ensuring data was created
print(f"Original training data shape: {X_23.shape}")
print(f"Augmented training data shape: {X_train_23_augmented.shape}")
# Out:
# Original training data shape: (7693, 23, 23, 1)
# Augmented training data shape: (9231, 23, 23, 1)

# %%
# repeat for 101
X_101 = np.stack(train_data_101["sequence"].values)  
y_101 = np.stack(train_data_101.drop(columns=['sequence']).values)  
X_aug = np.zeros((augment_size,) + X_101.shape[1:])
y_aug = np.zeros((augment_size,) + y_101.shape[1:])

for i in range(augment_size):
    # Get a random index
    idx = np.random.randint(0, len(X_101))
    img = X_101[idx].reshape((1,) + X_101[idx].shape)
    aug_img = next(datagen.flow(img, batch_size=1))[0]
    X_aug[i] = aug_img
    y_aug[i] = y_101[idx]

# Combining the data
X_train_101_augmented = np.concatenate([X_101, X_aug])
y_train_101_augmented = np.concatenate([y_101, y_aug])

X_train_101_augmented = np.asarray(X_train_101_augmented, dtype=np.float32)
y_train_101_augmented = np.asarray(y_train_101_augmented, dtype=np.float32)

# %%
# Ensuring data was created
print(f"Original training data shape: {X_101.shape}")
print(f"Augmented training data shape: {X_train_101_augmented.shape}")
# Out:
# Original training data shape: (7606, 101, 101, 1)
# Augmented training data shape: (9144, 101, 101, 1)

# %%
## Export this augmented data
np.save(os.path.join(STORED_DATA , 'cleaned_data', 'X_train_101_cleaned.json') , X_train_101_augmented)
np.save(os.path.join(STORED_DATA , 'cleaned_data', 'y_train_101_cleaned.json') , y_train_101_augmented)

np.save(os.path.join(STORED_DATA , 'cleaned_data', 'X_train_23_cleaned.json') , X_train_23_augmented)
np.save(os.path.join(STORED_DATA , 'cleaned_data', 'y_train_23_cleaned.json') , y_train_23_augmented)

# %% [markdown]
# Create new y classes for the new datasets (random sampled data aug)

# %%
y_train_labels_23 = np.argmax(y_train_23_augmented, axis=1)
class_labels_23 = np.unique(y_train_labels_23)
class_weights_23 = compute_class_weight(
  class_weight='balanced', 
  classes=class_labels_23,
  y=y_train_labels_23
)

class_weights_dict_23 = dict(enumerate(class_weights_23))

# %%
y_train_labels_101 = np.argmax(y_train_101_augmented, axis=1)
class_labels_101 = np.unique(y_train_labels_101)
class_weights_101 = compute_class_weight(
  class_weight='balanced', 
  classes=class_labels_101,
  y=y_train_labels_101
)

class_weights_dict_101 = dict(enumerate(class_weights_101))

# %% [markdown]
# ##### Creating Model
#
# The Idea behind my model is going to be as follows:
#
# 1. Input Layer
# 2. Conv2d * **n** amounts
# 3. BatchNormalize
# 4. Activation Relu
# 5. Maxpooling/bottleneck layer
# 6. Flatten
# 7. Dense - softmax (we are doing multiclass-classification)
#
# where layers 2-5 can be repeated **m** times.
#
# This follows the architecture for my baseline model.
#
# ##### Why this architecture?
#
# This is similar to the **ResNet50 Architecture** where **batchnorm is before relu**
#
# I will tune _m_ and _n_ close to what was shown in my **basemodel**
#
# Since my basemodel show that it will perform better with more data, it is likely that a simliar architecture will benefit from more data as well.
#
# **IF** i completely change the architecture (like 5 m and 3 n), it may result in poorer results.
#
# ##### What to Tune?
#
# I set **padding to be same to prevent sizing issues**
#
# I want to tune mainly:
#
# 1. Min Neurons
# 2. Dropout Values
# 3. Activation (ReLU / LeakyReLU)
# 4. Learning Rate (Adam)
# 5. Kernel_size (Max2DPool and Conv2D)
# 6. Regularizers (kernel, activity , l1l2 etc)

# %%
def create_model(n , m, 
            dropout, kernel_size, activation, starting_neurons,lr,
            kernel_regularization, activity_regularization,
            pooling_size
                 ):
  model = Sequential()

  # we want the neurons to be increasing, getting more complex further in
  neurons_arr = [32] # starting
  for _ in range(m -1 ):
    neurons_arr.append(neurons_arr[-1] *2)
  
  for i in range(m):
    # Adding n number of conv2d
    for _ in range(n):
      model.add(Conv2D(neurons_arr[i], kernel_size, strides=(1 ,1), padding='same', kernel_regularizer=l2(kernel_regularization), activity_regularizer=l1(activity_regularization)))

    # Batch Norm before Activatoin follows the resnet50 architecture
    model.add(BatchNormalization())
    model.add(eval(f'{activation}()'))
    model.add(MaxPooling2D((pooling_size) , padding='same'))

  
  model.add(Dropout(dropout))
  model.add(GlobalAveragePooling2D())
  model.add(Dense(128 , activation='relu'))
  model.add(Dropout(0.3)) # prevents overfitting from the previous dense layer
  model.add(Dense(11 , activation='softmax'))
  model.compile(loss='categorical_crossentropy' , optimizer=Adam(learning_rate=lr), metrics=[
    Precision(name='precision') , Recall(name='recall'), 'accuracy'
  ])
  return model

# %% [markdown]
# Note that tensor objects are not used in this param grid to ensure that it can be serialized and stored (using pickle)

# %%
hyper_params = { 
  'n': [1 , 2],
  'm': [3 , 4],
  'dropout': np.arange(0.6 , 0.9),
  'activation': ['ReLU' , 'LeakyReLU'],
  'kernel_size': [(3 , 3), (5 , 5)],
  'kernel_regularization': [0 , 1e-5 , 1e-6],
  'activity_regularization': [0 , 1e-6 , 1e-7],
  'pooling_size': [(2 ,2 ) , (3 ,3)],
  'starting_neurons': [32 , 64],
  'lr': [1e-4 , 1e-5 , 1e-6]
}
batch_sizes = [32 , 48, 64] 
fit_results = []
successful_params = []

# %% [markdown]
# ##### Tuning for 23x23

# %%
random_samples = random.sample(list(ParameterGrid(hyper_params)), 25)
# Random Search
for params in random_samples:
  for batch_size in batch_sizes:
    try:
      K.clear_session() # save gpu memory
      print(f'Tuning for {params}... \nbatch size {batch_size}')

      # Create and fit
      model = create_model(**params)
      early_stop = EarlyStopping(monitor='val_recall' , patience=10 , restore_best_weights=True, mode='max')
      fit_result = model.fit(
                X_train_23_augmented, y_train_23_augmented, epochs=100 , 
                batch_size=batch_size, 
                validation_data=(X_validation_23, y_validation_23) ,
                class_weight=class_weights_dict_23
                , callbacks=[early_stop]
                ,verbose = 0
                )

      # Eval and store 
      # will not be using cross val score since we have dedicated vaildation data.
      fit_results.append(fit_result.history)
      successful_params.append(dict(params , **{'batch_size': batch_size})) # this is required since im skipping bad params

      y_pred = model.predict(X_validation_23)
      y_pred = np.argmax(y_pred, axis=1)
      print(classification_report(np.argmax(y_validation_23, axis=1), y_pred))

    except Exception as error:
      # handles any bad params configurations
      print('Error occured with this param configuration')
      print(error)
      continue
K.clear_session()
# Out:
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'lr': 1e-05, 'm': 3, 'n': 2, 'pooling_size': (2, 2), 'starting_neurons': 32}...
# batch size 32
# 69/69 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75       200
#            1       0.79      0.87      0.83       200
#            2       0.73      0.83      0.78       200
#            3       0.74      0.64      0.68       200
#            4       0.91      0.82      0.87       200
#            5       0.52      0.81      0.64       200
#            6       0.87      0.62      0.73       200
#            7       0.82      0.78      0.79       200
#            8       0.71      0.78      0.74       200
#            9       0.83      0.69      0.76       200
#           10       0.81      0.68      0.74       200
#
#     accuracy                           0.75      2200
#    macro avg       0.77      0.75      0.75      2200
# weighted avg       0.77      0.75      0.75      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'lr': 1e-05, 'm': 3, 'n': 2, 'pooling_size': (2, 2), 'starting_neurons': 32}...
# batch size 48
# 69/69 [==============================] - 1s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.73      0.82      0.77       200
#            1       0.85      0.82      0.84       200
#            2       0.74      0.84      0.79       200
#            3       0.70      0.65      0.68       200
#            4       0.89      0.78      0.83       200
#            5       0.56      0.73      0.63       200
#            6       0.84      0.70      0.77       200
#            7       0.77      0.88      0.82       200
#            8       0.76      0.74      0.75       200
#            9       0.81      0.77      0.79       200
#           10       0.84      0.68      0.75       200
#
#     accuracy                           0.76      2200
#    macro avg       0.77      0.76      0.76      2200
# weighted avg       0.77      0.76      0.76      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'lr': 1e-05, 'm': 3, 'n': 2, 'pooling_size': (2, 2), 'starting_neurons': 32}...
# batch size 64
# 69/69 [==============================] - 1s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.69      0.73       200
#            1       0.87      0.82      0.84       200
#            2       0.73      0.89      0.80       200
#            3       0.82      0.56      0.66       200
#            4       0.92      0.83      0.88       200
#            5       0.66      0.63      0.64       200
#            6       0.64      0.84      0.73       200
#            7       0.73      0.85      0.78       200
#            8       0.76      0.79      0.77       200
#            9       0.90      0.70      0.79       200
#           10       0.72      0.77      0.74       200
#
#     accuracy                           0.76      2200
#    macro avg       0.77      0.76      0.76      2200
# weighted avg       0.77      0.76      0.76      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 0, 'dropout': 0.6, 'kernel_regularization': 1e-05, 'kernel_size': (3, 3), 'lr': 1e-06, 'm': 3, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 64}...
# batch size 32
# 69/69 [==============================] - 1s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       200
#            1       0.14      0.65      0.23       200
#            2       0.00      0.00      0.00       200
#            3       0.09      0.07      0.08       200
#            4       0.10      0.04      0.06       200
#            5       0.00      0.00      0.00       200
#            6       0.09      0.47      0.15       200
#            7       0.50      0.01      0.01       200
#            8       0.00      0.00      0.00       200
#            9       0.00      0.00      0.00       200
#           10       0.00      0.00      0.00       200
#
#     accuracy                           0.11      2200
#    macro avg       0.08      0.11      0.05      2200
# weighted avg       0.08      0.11      0.05      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 0, 'dropout': 0.6, 'kernel_regularization': 1e-05, 'kernel_size': (3, 3), 'lr': 1e-06, 'm': 3, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 64}...
# batch size 48
# 69/69 [==============================] - 1s 7ms/step
#               precision    recall  f1-score   support
#
#            0       0.16      0.18      0.17       200
#            1       0.67      0.11      0.19       200
#            2       0.16      0.05      0.08       200
#            3       0.18      0.02      0.04       200
#            4       0.67      0.06      0.11       200
#            5       0.21      0.17      0.19       200
#            6       0.16      0.11      0.13       200
#            7       0.28      0.53      0.37       200
#            8       0.17      0.46      0.24       200
#            9       0.16      0.47      0.24       200
#           10       0.53      0.10      0.17       200
#
#     accuracy                           0.20      2200
#    macro avg       0.30      0.21      0.17      2200
# weighted avg       0.30      0.20      0.17      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 0, 'dropout': 0.6, 'kernel_regularization': 1e-05, 'kernel_size': (3, 3), 'lr': 1e-06, 'm': 3, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 64}...
# batch size 64
# 69/69 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       200
#            1       0.00      0.00      0.00       200
#            2       0.00      0.00      0.00       200
#            3       0.00      0.00      0.00       200
#            4       0.00      0.00      0.00       200
#            5       0.00      0.00      0.00       200
#            6       0.08      0.60      0.14       200
#            7       0.03      0.12      0.05       200
#            8       0.00      0.00      0.00       200
#            9       0.00      0.00      0.00       200
#           10       0.00      0.00      0.00       200
#
#     accuracy                           0.07      2200
#    macro avg       0.01      0.07      0.02      2200
# weighted avg       0.01      0.07      0.02      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'lr': 0.0001, 'm': 3, 'n': 1, 'pooling_size': (2, 2), 'starting_neurons': 32}...
# batch size 32
# 69/69 [==============================] - 1s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.71      0.90      0.80       200
#            1       0.97      0.71      0.82       200
#            2       0.92      0.78      0.84       200
#            3       0.72      0.83      0.77       200
#            4       0.89      0.91      0.90       200
#            5       0.75      0.62      0.68       200
#            6       0.76      0.85      0.81       200
#            7       0.94      0.72      0.82       200
#            8       0.74      0.84      0.79       200
#            9       0.87      0.82      0.85       200
#           10       0.73      0.85      0.79       200
#
#     accuracy                           0.81      2200
#    macro avg       0.82      0.81      0.81      2200
# weighted avg       0.82      0.81      0.81      2200
#
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-06, 'dropout': 0.6, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'lr': 0.0001, 'm': 4, 'n': 1, 'pooling_size': (2, 2), 'starting_neurons': 64}...
# batch size 64
# 69/69 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80       200
#            1       0.88      0.87      0.87       200
#            2       0.75      0.91      0.82       200
#            3       0.85      0.66      0.74       200
#            4       0.95      0.86      0.90       200
#            5       0.70      0.77      0.73       200
#            6       0.84      0.81      0.83       200
#            7       0.91      0.86      0.88       200
#            8       0.77      0.88      0.82       200
#            9       0.89      0.87      0.88       200
#           10       0.75      0.85      0.80       200
#
#     accuracy                           0.83      2200
#    macro avg       0.83      0.83      0.83      2200
# weighted avg       0.83      0.83      0.83      2200
#
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-07, 'dropout': 0.6, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'lr': 1e-05, 'm': 4, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 32}...
# batch size 32
# 69/69 [==============================] - 1s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.77      0.73       200
#            1       0.80      0.80      0.80       200
#            2       0.70      0.85      0.77       200
#            3       0.78      0.64      0.70       200
#            4       0.88      0.81      0.85       200
#            5       0.71      0.62      0.67       200
#            6       0.81      0.74      0.78       200
#            7       0.80      0.85      0.82       200
#            8       0.74      0.78      0.76       200
#            9       0.83      0.81      0.82       200
#           10       0.73      0.76      0.75       200
#
#     accuracy                           0.77      2200
#    macro avg       0.77      0.77      0.77      2200
# weighted avg       0.77      0.77      0.77      2200
#
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-07, 'dropout': 0.6, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'lr': 1e-05, 'm': 4, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 32}...
# batch size 48
# 69/69 [==============================] - 1s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.79      0.74       200
#            1       0.82      0.79      0.80       200
#            2       0.82      0.78      0.79       200
#            3       0.70      0.67      0.68       200
#            4       0.86      0.86      0.86       200
#            5       0.60      0.69      0.64       200
#            6       0.70      0.82      0.76       200
#            7       0.95      0.70      0.81       200
#            8       0.68      0.80      0.73       200
#            9       0.90      0.72      0.80       200
#           10       0.79      0.75      0.77       200
#
#     accuracy                           0.76      2200
#    macro avg       0.77      0.76      0.76      2200
# weighted avg       0.77      0.76      0.76      2200
#
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-07, 'dropout': 0.6, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'lr': 1e-05, 'm': 4, 'n': 2, 'pooling_size': (3, 3), 'starting_neurons': 32}...
# batch size 64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 12
#      10 model = create_model(**params)
#      11 early_stop = EarlyStopping(monitor='val_recall' , patience=10 , restore_best_weights=True, mode='max')
# ---> 12 fit_result = model.fit(
#      13           X_train_23_augmented, y_train_23_augmented, epochs=100 ,
#      14           batch_size=batch_size,
#      15           validation_data=(X_validation_23, y_validation_23) ,
#      16           class_weight=class_weights_dict_23
#      17           , callbacks=[early_stop]
#      18           ,verbose = 0
#      19           )
#      21 # Eval and store
#      22 # will not be using cross val score since we have dedicated vaildation data.
#      23 fit_results.append(fit_result.history)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# Exporting 
results_23 = pd.DataFrame({
  'params': successful_params,
  'fit_results': fit_results
})

# %%
# attempt to pickle, if error just use .json format
with open(os.path.join('tuning_results' , '23_tuning_results_v5.pkl') , 'wb') as f:
  pickle.dump(results_23, f)

# %%
# Importing the results
results_23 = None

with open(os.path.join('tuning_results' , '23_tuning_results_v5.pkl') , 'rb') as f:
  results_23 = pickle.load(f)

# %% [markdown]
# ##### Tuning for 101

# %%
# redefined
fit_results = []
successful_params = []

# %%
gc.collect()
# Out:
# 35507

# %%
random_samples = random.sample(list(ParameterGrid(hyper_params)), 25)
# Random Search
for params in random_samples:
  for batch_size in batch_sizes:
    try:
      K.clear_session() # save gpu memory
      print(f'Tuning for {params}... \nbatch size {batch_size}')

      # Create and fit
      model = create_model(**params)
      early_stop = EarlyStopping(monitor='val_recall' , patience=10 , restore_best_weights=True, mode='max')
      fit_result = model.fit(
                X_train_101_augmented, y_train_101_augmented, epochs=100 , 
                batch_size=batch_size, 
                validation_data=(X_validation_101, y_validation_101) ,
                class_weight=class_weights_dict_101
                , callbacks=[early_stop]
                ,verbose = 0
                )

      # Eval and store 
      # will not be using cross val score since we have dedicated vaildation data.
      fit_results.append(fit_result.history)
      successful_params.append(dict(params , **{'batch_size': batch_size})) # this is required since im skipping bad params

      # 101 takes alot of space so i need to clear up my vram
      del model
    except Exception as error:
      # handles any bad params configurations
      print('Error occured with this param configuration')
      print(error)
      # we assume that the error is from overloaded memory
      gc.collect()
      break
K.clear_session()
# Out:
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 2s 33ms/step - loss: 1.7228 - precision: 0.5793 - recall: 0.4510 - accuracy: 0.5037
# Val loss: 1.7227962017059326 , val_accuracy: 0.5037002563476562, val recall: 0.4509713351726532
# Val precision: 0.5793226361274719 , val f1: 0.5071521034387134
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 2s 32ms/step - loss: 1.2839 - precision: 0.6582 - recall: 0.5888 - accuracy: 0.6253
# Val loss: 1.2838726043701172 , val_accuracy: 0.6253468990325928, val recall: 0.588806688785553
# Val precision: 0.6582213044166565 , val f1: 0.6215819977983994
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'sequential/conv2d_5/Conv2D' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\layers\convolutional\base_conv.py", line 283, in call
#       outputs = self.convolution_op(inputs, self.kernel)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\layers\convolutional\base_conv.py", line 255, in convolution_op
#       return tf.nn.convolution(
# Node: 'sequential/conv2d_5/Conv2D'
# OOM when allocating tensor with shape[64,3,3,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential/conv2d_5/Conv2D}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_272174]
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6000000000000001, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'm': 2, 'n': 1, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 1s 10ms/step - loss: 2.0129 - precision: 0.5860 - recall: 0.5088 - accuracy: 0.5338
# Val loss: 2.0129029750823975 , val_accuracy: 0.5337650179862976, val recall: 0.5087881684303284
# Val precision: 0.5860415697097778 , val f1: 0.5446892411759704
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6000000000000001, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'm': 2, 'n': 1, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 1s 9ms/step - loss: 1.0277 - precision: 0.8083 - recall: 0.5870 - accuracy: 0.6744
# Val loss: 1.02773916721344 , val_accuracy: 0.674375593662262, val recall: 0.5869565010070801
# Val precision: 0.8082802295684814 , val f1: 0.680064237101605
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.6000000000000001, 'kernel_regularization': 1e-06, 'kernel_size': (5, 5), 'm': 2, 'n': 1, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# 68/68 [==============================] - 1s 9ms/step - loss: 1.2989 - precision: 0.6843 - recall: 0.5324 - accuracy: 0.5967
# Val loss: 1.2989153861999512 , val_accuracy: 0.5966697335243225, val recall: 0.5323774218559265
# Val precision: 0.684304416179657 , val f1: 0.5988553120769613
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-07, 'dropout': 0.5, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 2s 22ms/step - loss: 0.3415 - precision: 0.9358 - recall: 0.9167 - accuracy: 0.9265
# Val loss: 0.3415261507034302 , val_accuracy: 0.9264569878578186, val recall: 0.9167437553405762
# Val precision: 0.9357884526252747 , val f1: 0.926168160819849
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-07, 'dropout': 0.5, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 997, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 576, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 634, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 510, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3'
# OOM when allocating tensor with shape[64,32,101,101] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_446522]
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.7000000000000002, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 1s 20ms/step - loss: 0.2240 - precision: 0.9467 - recall: 0.9357 - accuracy: 0.9413
# Val loss: 0.2239638715982437 , val_accuracy: 0.9412580728530884, val recall: 0.935707688331604
# Val precision: 0.946654200553894 , val f1: 0.9411490657800023
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.7000000000000002, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 1s 19ms/step - loss: 0.3095 - precision: 0.9232 - recall: 0.9117 - accuracy: 0.9163
# Val loss: 0.30946609377861023 , val_accuracy: 0.9162812232971191, val recall: 0.9116559028625488
# Val precision: 0.9231849908828735 , val f1: 0.9173841757857005
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 0, 'dropout': 0.7000000000000002, 'kernel_regularization': 0, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'sequential/conv2d_2/ActivityRegularizer/Abs' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1100, in __call__
#       self._handle_activity_regularization(inputs, outputs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 2782, in _handle_activity_regularization
#       self._activity_regularizer(output)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\regularizers.py", line 285, in __call__
#       return self.l1 * tf.reduce_sum(tf.abs(x))
# Node: 'sequential/conv2d_2/ActivityRegularizer/Abs'
# failed to allocate memory
# 	 [[{{node sequential/conv2d_2/ActivityRegularizer/Abs}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_582968]
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 2s 23ms/step - loss: 0.9939 - precision: 0.8142 - recall: 0.7197 - accuracy: 0.7636
# Val loss: 0.9939145445823669 , val_accuracy: 0.7636447548866272, val recall: 0.7197039723396301
# Val precision: 0.8142333626747131 , val f1: 0.7640559153874046
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 2s 22ms/step - loss: 0.3345 - precision: 0.9587 - recall: 0.9450 - accuracy: 0.9482
# Val loss: 0.3344862461090088 , val_accuracy: 0.9481961131095886, val recall: 0.9449583888053894
# Val precision: 0.9587048292160034 , val f1: 0.9517819271713465
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'sequential/conv2d_2/ActivityRegularizer/Abs' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1100, in __call__
#       self._handle_activity_regularization(inputs, outputs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 2782, in _handle_activity_regularization
#       self._activity_regularizer(output)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\regularizers.py", line 285, in __call__
#       return self.l1 * tf.reduce_sum(tf.abs(x))
# Node: 'sequential/conv2d_2/ActivityRegularizer/Abs'
# failed to allocate memory
# 	 [[{{node sequential/conv2d_2/ActivityRegularizer/Abs}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_687184]
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 4, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 3s 49ms/step - loss: 0.9345 - precision: 0.8638 - recall: 0.7276 - accuracy: 0.7993
# Val loss: 0.9345094561576843 , val_accuracy: 0.7992599606513977, val recall: 0.7275670766830444
# Val precision: 0.8638110756874084 , val f1: 0.7898568403937462
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 4, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 3s 48ms/step - loss: 0.8885 - precision: 0.8234 - recall: 0.7007 - accuracy: 0.7664
# Val loss: 0.888452410697937 , val_accuracy: 0.7664200067520142, val recall: 0.7007400393486023
# Val precision: 0.823369562625885 , val f1: 0.7571213790784755
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 4, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'sequential/conv2d_3/ActivityRegularizer/Abs' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1100, in __call__
#       self._handle_activity_regularization(inputs, outputs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 2782, in _handle_activity_regularization
#       self._activity_regularizer(output)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\regularizers.py", line 285, in __call__
#       return self.l1 * tf.reduce_sum(tf.abs(x))
# Node: 'sequential/conv2d_3/ActivityRegularizer/Abs'
# failed to allocate memory
# 	 [[{{node sequential/conv2d_3/ActivityRegularizer/Abs}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_796090]
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-06, 'dropout': 0.4, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 4, 'n': 1, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 1s 19ms/step - loss: 0.5363 - precision: 0.9185 - recall: 0.8867 - accuracy: 0.8982
# Val loss: 0.5363435745239258 , val_accuracy: 0.8982423543930054, val recall: 0.8866789937019348
# Val precision: 0.9185433387756348 , val f1: 0.9023298942495442
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-06, 'dropout': 0.4, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 4, 'n': 1, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 1s 18ms/step - loss: 0.7453 - precision: 0.8620 - recall: 0.7919 - accuracy: 0.8265
# Val loss: 0.7452904582023621 , val_accuracy: 0.8265494704246521, val recall: 0.7918593883514404
# Val precision: 0.862034261226654 , val f1: 0.8254580114436695
# Tuning for {'activation': 'LeakyReLU', 'activity_regularization': 1e-06, 'dropout': 0.4, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 4, 'n': 1, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 128
# 68/68 [==============================] - 1s 18ms/step - loss: 0.7399 - precision: 0.8544 - recall: 0.8145 - accuracy: 0.8330
# Val loss: 0.7399065494537354 , val_accuracy: 0.8330249786376953, val recall: 0.8145235776901245
# Val precision: 0.8544396162033081 , val f1: 0.8340042176560106
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 2, 'n': 1, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 1s 13ms/step - loss: 1.5479 - precision: 0.6451 - recall: 0.4339 - accuracy: 0.5356
# Val loss: 1.5479313135147095 , val_accuracy: 0.5356151461601257, val recall: 0.4338575303554535
# Val precision: 0.645116925239563 , val f1: 0.5188052573132119
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 2, 'n': 1, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1)}...
# batch size 64
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
# ...
# batch size 32
# 68/68 [==============================] - 2s 29ms/step - loss: 0.3492 - precision: 0.9183 - recall: 0.8686 - accuracy: 0.8876
# Val loss: 0.34916359186172485 , val_accuracy: 0.8876040577888489, val recall: 0.868640124797821
# Val precision: 0.9183374047279358 , val f1: 0.8927976541721822
# Tuning for {'activation': 'ReLU', 'activity_regularization': 0, 'dropout': 0.7000000000000002, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 2, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 2s 29ms/step - loss: 1.6858 - precision: 0.6589 - recall: 0.5467 - accuracy: 0.5814
# Val loss: 1.6857577562332153 , val_accuracy: 0.5814061164855957, val recall: 0.5467159748077393
# Val precision: 0.6588628888130188 , val f1: 0.5975732447092783
# Tuning for {'activation': 'ReLU', 'activity_regularization': 0, 'dropout': 0.7000000000000002, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 2, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'sequential/batch_normalization/FusedBatchNormV3' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 993, in train_step
#       y_pred = self(x, training=True)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 557, in __call__
#       return super().__call__(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\sequential.py", line 410, in call
#       return super().call(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 510, in call
#       return self._run_internal_graph(inputs, training=training, mask=mask)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\functional.py", line 667, in _run_internal_graph
#       outputs = node.layer(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\base_layer.py", line 1097, in __call__
#       outputs = call_fn(inputs, *args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 96, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 850, in call
#       outputs = self._fused_batch_norm(inputs, training=training)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 660, in _fused_batch_norm
#       output, mean, variance = control_flow_util.smart_cond(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\control_flow_util.py", line 108, in smart_cond
#       return tf.__internal__.smart_cond.smart_cond(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\layers\normalization\batch_normalization.py", line 634, in _fused_batch_norm_training
#       return tf.compat.v1.nn.fused_batch_norm(
# Node: 'sequential/batch_normalization/FusedBatchNormV3'
# OOM when allocating tensor with shape[128,32,101,101] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node sequential/batch_normalization/FusedBatchNormV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_2757030]
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-07, 'dropout': 0.6000000000000001, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 32
# 68/68 [==============================] - 2s 23ms/step - loss: 0.4517 - precision: 0.9247 - recall: 0.8978 - accuracy: 0.9098
# Val loss: 0.4517418146133423 , val_accuracy: 0.9098057150840759, val recall: 0.8977798223495483
# Val precision: 0.9247260689735413 , val f1: 0.911053691870016
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-07, 'dropout': 0.6000000000000001, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 64
# 68/68 [==============================] - 1s 22ms/step - loss: 0.4461 - precision: 0.9167 - recall: 0.8751 - accuracy: 0.8959
# Val loss: 0.44613906741142273 , val_accuracy: 0.8959296941757202, val recall: 0.8751156330108643
# Val precision: 0.9166666865348816 , val f1: 0.8954093297224291
# Tuning for {'activation': 'ReLU', 'activity_regularization': 1e-07, 'dropout': 0.6000000000000001, 'kernel_regularization': 0, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1)}...
# batch size 128
# Error occured with this param configuration
# Graph execution error:
#
# Detected at node 'gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3' defined at (most recent call last):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#       app.launch_new_instance()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#       app.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#       self.io_loop.start()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#       self.asyncio_loop.run_forever()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 570, in run_forever
#       self._run_once()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\base_events.py", line 1859, in _run_once
#       handle._run()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\asyncio\events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#       await self.process_one()
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#       await dispatch(*args)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#       await result
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#       await super().execute_request(stream, ident, parent)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#       reply_content = await reply_content
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#       res = shell.run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#       result = self._run_cell(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#       result = runner(coro)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "C:\Users\JOVAN\AppData\Local\Temp\ipykernel_12340\2023695108.py", line 12, in <module>
#       fit_result = model.fit(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\utils\traceback_utils.py", line 65, in error_handler
#       return fn(*args, **kwargs)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1564, in fit
#       tmp_logs = self.train_function(iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1160, in train_function
#       return step_function(self, iterator)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1146, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 1135, in run_step
#       outputs = model.train_step(data)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\engine\training.py", line 997, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 576, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 634, in _compute_gradients
#       grads_and_vars = self._get_gradients(
#     File "c:\Users\JOVAN\anaconda3\envs\gpu_env2\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py", line 510, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3'
# OOM when allocating tensor with shape[128,32,101,101] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/sequential/batch_normalization/FusedBatchNormGradV3}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_2852908]

# %%
# Exporting 
results_101 = pd.DataFrame({
  'params': successful_params,
  'fit_results': fit_results
})

# %%
# attempt to pickle, if error just use .json format
with open(os.path.join('tuning_results' , '101_tuning_results_v4.pkl') , 'wb') as f:
  pickle.dump(results_101, f)

# %%
# Importing the results
results_101 = None

with open(os.path.join('tuning_results' , '101_tuning_results_v4.pkl') , 'rb') as f:
  results_101 = pickle.load(f)

# %% [markdown]
# ##### Evaluating and choosing params

# %%
# Deconstructing Results

val_accuracies_23 = results_23['validation_accuracies']
val_losses_23 = results_23['validation_losses']
val_f1_23 = results_23['validation_f1']
successful_params_23 = results_23['params']
fit_results_23 = results_23['fit_results']
                   
val_accuracies_101 = results_101['validation_accuracies']
val_losses_101 = results_101['validation_losses']
val_f1_101 = results_101['validation_f1']
successful_params_101 = results_101['params']
fit_results_101 = results_101['fit_results']

# %% [markdown]
# ##### Best Model Analysis

# %%
best_index_23 = np.argmax(val_f1_23)
best_index_101 = np.argmax(val_f1_101)

# %%
print(f'Best_params 23: {successful_params_23[best_index_23]}')
print(f'Best_f1 23: {val_f1_23[best_index_23]}')
print(f'Best_params 101: {successful_params_101[best_index_101]}')
print(f'Best_f1 101: {val_f1_101[best_index_101]}')
# Out:
# Best_params 23: {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1), 'batch_size': 32}
# Best_f1 23: 0.8850205628651956
# Best_params 101: {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1), 'batch_size': 64}
# Best_f1 101: 0.9517819271713465

# %% [markdown]
# For now i want to look at the loss and learning rates
#
# Mainly i want to see if my model is overfitting or underfitting

# %%
fig , ax = plt.subplots(1 , 2 , figsize=(16 , 6))
epochs = range(1, len(fit_results_23[best_index_23]['val_loss']) + 1)

# loss
ax[0].plot(epochs , fit_results_23[best_index_23]['val_loss'], label='validation')
ax[0].plot(epochs , fit_results_23[best_index_23]['loss'] , label='train')
ax[0].legend()
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('loss')
ax[0].set_title('loss against epochs')

# acc
ax[1].plot(epochs , fit_results_23[best_index_23]['f1_score'] , label='train')
ax[1].plot(epochs , fit_results_23[best_index_23]['val_f1_score'], label='validation')
ax[1].legend()
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('f1')
ax[1].set_title('f1 against epochs')
plt.show()

# %%
fig , ax = plt.subplots(1 , 2 , figsize=(16 , 6))
epochs = range(1, len(fit_results_101[best_index_101]['val_loss']) + 1)

# loss
ax[0].plot(epochs , fit_results_101[best_index_101]['val_loss'], label='validation')
ax[0].plot(epochs , fit_results_101[best_index_101]['loss'] , label='train')
ax[0].legend()
ax[0].set_xlabel('epochs')
ax[0].set_ylabel('loss')
ax[0].set_title('loss against epochs')

# acc
ax[1].plot(epochs , fit_results_101[best_index_101]['f1_score'] , label='train')
ax[1].plot(epochs , fit_results_101[best_index_101]['val_f1_score'], label='validation')
ax[1].legend()
ax[1].set_xlabel('epochs')
ax[1].set_ylabel('f1')
ax[1].set_title('f1 against epochs')
plt.show()

# %% [markdown]
# ##### Making Predictions

# %% [markdown]
# The results suggests that using all the training data is optimal for this problem
#
# I want to try the top 2 models and compare them against each other
#
# ##### Choice of Epochs
#
# I will use early stop with patience 3.
#
# With **restore_best_weights**, it should be able to capture the point **right before overfitting**
#
# Though if i feel like it is unable to i will analyse the graph further and manually set the epoch

# %%
params_to_consider = [best_index_23 , best_index_101]

# %%
params = successful_params_23[best_index_23] 
print(f'Testing {successful_params_23[best_index_23]}')
model_params = {k:v for k , v in params.items() if k != 'batch_size'}
# callbacks
early_stopper = EarlyStopping(patience=10 , monitor='val_recall', restore_best_weights=True, mode='max')
model_checkpoint = ModelCheckpoint(filepath=os.path.join('stored_models' , f'best_weights_params_set{i}_size_23_v5.h5'),
                                    monitor='val_recall',
                                    save_best_only=True,
                                    save_weight_only=True,                                    
                                    mode='max'
                                   )
# fitting
model = create_model(**model_params)
results = model.fit(X_train_23_augmented, y_train_23_augmented,
                    epochs=50,
                    batch_size=params['batch_size'],
                    callbacks=[early_stopper , model_checkpoint],
                    validation_data = (X_validation_23, y_validation_23),
                    class_weight=class_weights_dict_23,
                    verbose=1
                    )
epochs = len(results.history['loss'])
# predict
y_pred = model.predict(X_test_23)
y_pred = np.argmax(y_pred, axis=1) # in non-onehot encoded format

## results
y_test_labels = np.argmax(y_test_23, axis=1)
print(classification_report(y_test_labels , y_pred))
cm = confusion_matrix(y_test_labels , y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_data_23.columns[1:])
disp.plot()
plt.xticks(rotation=90)
plt.show()
# Out:
# Testing {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-05, 'kernel_size': (5, 5), 'm': 3, 'n': 2, 'padding': 'same', 'pooling_size': (2, 2), 'strides': (1, 1), 'batch_size': 32}
# Epoch 1/50
# 289/289 [==============================] - 13s 28ms/step - loss: 1.9976 - precision: 0.5741 - recall: 0.0764 - accuracy: 0.3240 - val_loss: 3.7224 - val_precision: 0.2436 - val_recall: 0.1209 - val_accuracy: 0.1491 - f1_score: 0.1348 - val_f1_score: 0.1616
# Epoch 2/50
# 289/289 [==============================] - 6s 22ms/step - loss: 1.5527 - precision: 0.6914 - recall: 0.2830 - accuracy: 0.5014 - val_loss: 2.1327 - val_precision: 0.4871 - val_recall: 0.3182 - val_accuracy: 0.4064 - f1_score: 0.4016 - val_f1_score: 0.3849
# Epoch 3/50
# 289/289 [==============================] - 6s 20ms/step - loss: 1.2560 - precision: 0.7536 - recall: 0.4525 - accuracy: 0.6091 - val_loss: 1.4273 - val_precision: 0.6646 - val_recall: 0.4945 - val_accuracy: 0.5782 - f1_score: 0.5655 - val_f1_score: 0.5671
# Epoch 4/50
# 289/289 [==============================] - 6s 20ms/step - loss: 1.0276 - precision: 0.7956 - recall: 0.5647 - accuracy: 0.6894 - val_loss: 1.4356 - val_precision: 0.6240 - val_recall: 0.4791 - val_accuracy: 0.5559 - f1_score: 0.6606 - val_f1_score: 0.5420
# Epoch 5/50
# 289/289 [==============================] - 6s 19ms/step - loss: 0.8995 - precision: 0.8241 - recall: 0.6388 - accuracy: 0.7324 - val_loss: 1.2110 - val_precision: 0.7091 - val_recall: 0.6159 - val_accuracy: 0.6609 - f1_score: 0.7197 - val_f1_score: 0.6592
# Epoch 6/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.7539 - precision: 0.8524 - recall: 0.7129 - accuracy: 0.7850 - val_loss: 1.4185 - val_precision: 0.6635 - val_recall: 0.5736 - val_accuracy: 0.6118 - f1_score: 0.7764 - val_f1_score: 0.6153
# Epoch 7/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0
50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.2745 - precision: 0.9638 - recall: 0.9539 - accuracy: 0.9582 - val_loss: 1.1577 - val_precision: 0.8061 - val_recall: 0.7823 - val_accuracy: 0.7895 - f1_score: 0.9588 - val_f1_score: 0.7940
# Epoch 41/50
# 289/289 [==============================] - 6s 19ms/step - loss: 0.2440 - precision: 0.9730 - recall: 0.9638 - accuracy: 0.9682 - val_loss: 0.7170 - val_precision: 0.8800 - val_recall: 0.8600 - val_accuracy: 0.8655 - f1_score: 0.9684 - val_f1_score: 0.8699
# Epoch 42/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.2118 - precision: 0.9784 - recall: 0.9743 - accuracy: 0.9763 - val_loss: 0.7825 - val_precision: 0.8692 - val_recall: 0.8491 - val_accuracy: 0.8541 - f1_score: 0.9763 - val_f1_score: 0.8590
# Epoch 43/50
# 289/289 [==============================] - 5s 19ms/step - loss: 0.2315 - precision: 0.9731 - recall: 0.9656 - accuracy: 0.9695 - val_loss: 0.6911 - val_precision: 0.8788 - val_recall: 0.8600 - val_accuracy: 0.8650 - f1_score: 0.9693 - val_f1_score: 0.8693
# Epoch 44/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.2192 - precision: 0.9795 - recall: 0.9723 - accuracy: 0.9748 - val_loss: 1.0026 - val_precision: 0.8385 - val_recall: 0.8168 - val_accuracy: 0.8255 - f1_score: 0.9759 - val_f1_score: 0.8275
# Epoch 45/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.2284 - precision: 0.9724 - recall: 0.9657 - accuracy: 0.9689 - val_loss: 1.7705 - val_precision: 0.7277 - val_recall: 0.6986 - val_accuracy: 0.7100 - f1_score: 0.9690 - val_f1_score: 0.7129
# Epoch 46/50
# 289/289 [==============================] - 5s 18ms/step - loss: 0.2377 - precision: 0.9737 - recall: 0.9659 - accuracy: 0.9701 - val_loss: 0.9284 - val_precision: 0.8363 - val_recall: 0.8105 - val_accuracy: 0.8186 - f1_score: 0.9698 - val_f1_score: 0.8232
# Epoch 47/50
# 289/289 [==============================] - 5s 19ms/step - loss: 0.2226 - precision: 0.9777 - recall: 0.9724 - accuracy: 0.9750 - val_loss: 0.8054 - val_precision: 0.8545 - val_recall: 0.8195 - val_accuracy: 0.8286 - f1_score: 0.9750 - val_f1_score: 0.8367
# 69/69 [==============================] - 1s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.70      0.97      0.81       200
#            1       0.95      0.90      0.92       200
#            2       0.93      0.88      0.90       200
#            3       0.96      0.69      0.81       200
#            4       0.94      0.97      0.96       200
#            5       0.80      0.69      0.74       200
#            6       0.81      0.94      0.87       200
#            7       0.91      0.91      0.91       200
#            8       0.91      0.88      0.89       200
#            9       0.93      0.89      0.91       200
#           10       0.86      0.86      0.86       200
#
#     accuracy                           0.87      2200
#    macro avg       0.88      0.87      0.87      2200
# weighted avg       0.88      0.87      0.87      2200

# %% [markdown]
# ### 101 x 101
#
# Now i can do the exact same steps for 101x101 size

# %%
params = successful_params_101[best_index_101] 
print(f'Testing {successful_params_101[best_index_101]}')
model_params = {k:v for k , v in params.items() if k != 'batch_size'}
# callbacks
early_stopper = EarlyStopping(patience=10 , monitor='val_recall', restore_best_weights=True, mode='max')
model_checkpoint = ModelCheckpoint(filepath=os.path.join('stored_models' , f'best_weights_params_set{i}_size_101_v5.h5'),
                                    monitor='val_recall',
                                    save_best_only=True,
                                    save_weight_only=True,                                    
                                    mode='max'
                                   )
# fitting
model = create_model(**model_params)
results = model.fit(X_train_101_augmented, y_train_101_augmented,
                    epochs=50,
                    batch_size=params['batch_size'],
                    callbacks=[early_stopper , model_checkpoint],
                    validation_data = (X_validation_101, y_validation_101),
                    class_weight=class_weights_dict_101,
                    verbose=1
                    )
# predict
y_pred = model.predict(X_test_101)
y_pred = np.argmax(y_pred, axis=1) # in non-onehot encoded format

## results
y_test_labels = np.argmax(y_test_101, axis=1)
print(classification_report(y_test_labels , y_pred))
cm = confusion_matrix(y_test_labels , y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_data_101.columns[1:])
disp.plot()
plt.xticks(rotation=90)
plt.show()
# Out:
# Testing {'activation': 'ReLU', 'activity_regularization': 1e-06, 'dropout': 0.3, 'kernel_regularization': 1e-06, 'kernel_size': (3, 3), 'm': 4, 'n': 3, 'padding': 'same', 'pooling_size': (3, 3), 'strides': (1, 1), 'batch_size': 64}
# Epoch 1/50
# 143/143 [==============================] - 29s 170ms/step - loss: 1.9768 - precision: 0.6473 - recall: 0.1728 - accuracy: 0.3852 - val_loss: 6.6004 - val_precision: 0.0925 - val_recall: 0.0925 - val_accuracy: 0.0925 - f1_score: 0.2728 - val_f1_score: 0.0925
# Epoch 2/50
# 143/143 [==============================] - 24s 165ms/step - loss: 1.4794 - precision: 0.7344 - recall: 0.4216 - accuracy: 0.5829 - val_loss: 5.2906 - val_precision: 0.1275 - val_recall: 0.0897 - val_accuracy: 0.0916 - f1_score: 0.5357 - val_f1_score: 0.1053
# Epoch 3/50
# 143/143 [==============================] - 23s 163ms/step - loss: 1.1013 - precision: 0.8101 - recall: 0.6164 - accuracy: 0.7166 - val_loss: 4.6846 - val_precision: 0.1218 - val_recall: 0.1068 - val_accuracy: 0.1142 - f1_score: 0.7001 - val_f1_score: 0.1138
# Epoch 4/50
# 143/143 [==============================] - 24s 165ms/step - loss: 0.9689 - precision: 0.8435 - recall: 0.6985 - accuracy: 0.7712 - val_loss: 3.3637 - val_precision: 0.2417 - val_recall: 0.2031 - val_accuracy: 0.2160 - f1_score: 0.7642 - val_f1_score: 0.2207
# Epoch 5/50
# 143/143 [==============================] - 24s 166ms/step - loss: 0.7789 - precision: 0.8802 - recall: 0.7873 - accuracy: 0.8314 - val_loss: 0.9646 - val_precision: 0.7890 - val_recall: 0.7040 - val_accuracy: 0.7470 - f1_score: 0.8311 - val_f1_score: 0.7441
# Epoch 6/50
# 143/143 [==============================] - 23s 164ms/step - loss: 0.6979 - precision: 0.8962 - recall: 0.8202 - accuracy: 0.8560 - val_loss: 2.8482 - val_precision: 0.5034 - val_recall: 0.4440 - val_accuracy: 0.4653 - f1_score: 0.8565 - val_f1_score: 0.4719
# Epoch 7/50
# 143/143 [==============================] - 24s 165ms/step - loss: 0.6513 - precision: 0.9017 - recall: 0.8375 - accuracy: 0.8693 - val_loss: 3.1642 - val_precision: 0.4298 - val_recall: 0.3784 - val_accuracy: 0.4052 - f1_score: 0.8684 - val_f1_score: 0.4025
# Epoch 8/50
# 143/143 [==============================] - 24s 170ms/step - loss: 0.6466 - precision: 0.9109 - recall: 0.8501 - accuracy: 0.8794 - val_loss: 1.4174 - val_precision: 0.6976 - val_recall: 0.6369 - val_accuracy: 0.6577 - f1_score: 0.8794 - val_f1_score: 0.6659
# 143/143 [==============================] - 25s 172ms/step - loss: 0.3117 - precision: 0.9663 - recall: 0.9560 - accuracy: 0.9607 - val_loss: 3.2488 - val_precision: 0.4756 - val_recall: 0.4454 - val_accuracy: 0.4611 - f1_score: 0.9611 - val_f1_score: 0.4600
# Epoch 30/50
# 143/143 [==============================] - 24s 169ms/step - loss: 0.3150 - precision: 0.9698 - recall: 0.9577 - accuracy: 0.9626 - val_loss: 0.9454 - val_precision: 0.8259 - val_recall: 0.7988 - val_accuracy: 0.8113 - f1_score: 0.9637 - val_f1_score: 0.8121
# Epoch 31/50
# 143/143 [==============================] - 24s 169ms/step - loss: 0.2665 - precision: 0.9766 - recall: 0.9686 - accuracy: 0.9716 - val_loss: 3.0937 - val_precision: 0.5280 - val_recall: 0.5014 - val_accuracy: 0.5130 - f1_score: 0.9726 - val_f1_score: 0.5144
# Epoch 32/50
# 143/143 [==============================] - 24s 168ms/step - loss: 0.2932 - precision: 0.9711 - recall: 0.9607 - accuracy: 0.9659 - val_loss: 1.3219 - val_precision: 0.7642 - val_recall: 0.7451 - val_accuracy: 0.7553 - f1_score: 0.9659 - val_f1_score: 0.7546
# Epoch 33/50
# 143/143 [==============================] - 25s 176ms/step - loss: 0.2790 - precision: 0.9728 - recall: 0.9652 - accuracy: 0.9687 - val_loss: 2.3323 - val_precision: 0.6856 - val_recall: 0.6485 - val_accuracy: 0.6628 - f1_score: 0.9690 - val_f1_score: 0.6665
# Epoch 34/50
# 143/143 [==============================] - 25s 178ms/step - loss: 0.2725 - precision: 0.9732 - recall: 0.9639 - accuracy: 0.9684 - val_loss: 2.7373 - val_precision: 0.5241 - val_recall: 0.4736 - val_accuracy: 0.4963 - f1_score: 0.9685 - val_f1_score: 0.4976
# Epoch 35/50
# 143/143 [==============================] - 25s 172ms/step - loss: 0.2846 - precision: 0.9714 - recall: 0.9633 - accuracy: 0.9670 - val_loss: 0.5073 - val_precision: 0.9182 - val_recall: 0.8982 - val_accuracy: 0.9089 - f1_score: 0.9673 - val_f1_score: 0.9081
# 68/68 [==============================] - 2s 19ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88       200
#            1       0.99      0.91      0.95       200
#            2       0.93      0.96      0.95       200
#            3       0.95      0.94      0.95       200
#            4       0.97      0.94      0.95       190
#            5       0.90      0.90      0.90       198
#            6       0.90      0.96      0.93       200
#            7       0.90      0.95      0.93       175
#            8       0.97      0.90      0.94       199
#            9       0.98      0.88      0.93       200
#           10       0.98      0.88      0.92       200
#
#     accuracy                           0.93      2162
#    macro avg       0.93      0.93      0.93      2162
# weighted avg       0.93      0.93      0.93      2162

# %% [markdown]
# ##### Evaluating against baseline model

# %%
# 101
# callbacks
early_stopper = EarlyStopping(patience=10 , monitor='val_f1_score', restore_best_weights=True, mode='max')
model_checkpoint = ModelCheckpoint(filepath=os.path.join('stored_models' , f'best_weights_params_set{i}_size_101_v4.h5'),
                                    monitor='val_f1_score',
                                    save_best_only=True,
                                    save_weight_only=True,                                    
                                    mode='max'
                                   )
# fitting
model = create_baseline_model()
results = model.fit(X_train_101_augmented, y_train_101_augmented,
                    epochs=50,
                    batch_size=32,
                    callbacks=[F1ScoreCallback() , early_stopper , model_checkpoint],
                    validation_data = (X_validation_101, y_validation_101),
                    class_weight=class_weights_dict_101,
                    verbose=1
                    )
# predict
y_pred = model.predict(X_test_101)
y_pred = np.argmax(y_pred, axis=1) # in non-onehot encoded format

## results
y_test_labels = np.argmax(y_test_101, axis=1)
print(classification_report(y_test_labels , y_pred))
cm = confusion_matrix(y_test_labels , y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=test_data_101.columns[1:])
disp.plot()
plt.xticks(rotation=90)
plt.show()
# Out:
# Epoch 1/50
#   5/286 [..............................] - ETA: 19s - loss: 2.6960 - precision: 0.4000 - recall: 0.0375 - accuracy: 0.0938WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0333s vs `on_train_batch_end` time: 0.0337s). Check your callbacks.
# 286/286 [==============================] - 12s 34ms/step - loss: 1.8114 - precision: 0.6567 - recall: 0.1267 - accuracy: 0.3715 - val_loss: 4.1152 - val_precision: 0.0798 - val_recall: 0.0148 - val_accuracy: 0.0814 - f1_score: 0.2125 - val_f1_score: 0.0250
# Epoch 2/50
# 286/286 [==============================] - 9s 31ms/step - loss: 1.3622 - precision: 0.7306 - recall: 0.3177 - accuracy: 0.5335 - val_loss: 5.3891 - val_precision: 0.2433 - val_recall: 0.1517 - val_accuracy: 0.1859 - f1_score: 0.4428 - val_f1_score: 0.1869
# Epoch 3/50
# 286/286 [==============================] - 14s 47ms/step - loss: 1.0885 - precision: 0.7815 - recall: 0.4648 - accuracy: 0.6277 - val_loss: 1.8810 - val_precision: 0.6239 - val_recall: 0.4089 - val_accuracy: 0.5176 - f1_score: 0.5829 - val_f1_score: 0.4940
# Epoch 4/50
# 286/286 [==============================] - 13s 44ms/step - loss: 0.9446 - precision: 0.8022 - recall: 0.5554 - accuracy: 0.6827 - val_loss: 1.7625 - val_precision: 0.4993 - val_recall: 0.3312 - val_accuracy: 0.4292 - f1_score: 0.6564 - val_f1_score: 0.3982
# Epoch 5/50
# 286/286 [==============================] - 13s 45ms/step - loss: 0.8186 - precision: 0.8314 - recall: 0.6238 - accuracy: 0.7224 - val_loss: 1.2087 - val_precision: 0.6905 - val_recall: 0.4995 - val_accuracy: 0.5851 - f1_score: 0.7128 - val_f1_score: 0.5797
# Epoch 6/50
# 286/286 [==============================] - 13s 46ms/step - loss: 0.7007 - precision: 0.8527 - recall: 0.6775 - accuracy: 0.7674 - val_loss: 2.6594 - val_precision: 0.4352 - val_recall: 0.3885 - val_accuracy: 0.4052 - f1_score: 0.7551 - val_f1_score: 0.4106
# Epoch 7/50
# 286/286 [==============================] - 13s 44ms/step - loss: 0.6335 - precision: 0.8621 - recall: 0.7192 - accuracy: 0.7901 - val_loss: 2.6259 - val_precision: 0.4806 - val_recall: 0.4237 - val_accuracy: 0.4459 - f1_score: 0.7842 - val_f1_score: 0.4503
# Epoch 8/50
# 286/286 [==============================] - 12s 44ms/step - loss: 0.5806 - precision: 0.8714 - recall: 0.7528 - accuracy: 0.8094 - val_loss: 1.4576 - val_precision: 0.6445 - val_recall: 0.5241 - val_accuracy: 0.5643 - f1_score: 0.8078 - val_f1_score: 0.5781
# 286/286 [==============================] - 12s 43ms/step - loss: 0.1761 - precision: 0.9537 - recall: 0.9325 - accuracy: 0.9429 - val_loss: 1.6365 - val_precision: 0.6572 - val_recall: 0.6129 - val_accuracy: 0.6314 - f1_score: 0.9430 - val_f1_score: 0.6343
# Epoch 30/50
# 286/286 [==============================] - 12s 43ms/step - loss: 0.1877 - precision: 0.9502 - recall: 0.9278 - accuracy: 0.9377 - val_loss: 5.8287 - val_precision: 0.3260 - val_recall: 0.3201 - val_accuracy: 0.3233 - f1_score: 0.9389 - val_f1_score: 0.3230
# Epoch 31/50
# 286/286 [==============================] - 15s 54ms/step - loss: 0.1674 - precision: 0.9535 - recall: 0.9345 - accuracy: 0.9426 - val_loss: 2.8609 - val_precision: 0.5705 - val_recall: 0.5486 - val_accuracy: 0.5564 - f1_score: 0.9439 - val_f1_score: 0.5593
# Epoch 32/50
# 286/286 [==============================] - 14s 50ms/step - loss: 0.1461 - precision: 0.9599 - recall: 0.9432 - accuracy: 0.9514 - val_loss: 1.8983 - val_precision: 0.6579 - val_recall: 0.6332 - val_accuracy: 0.6420 - f1_score: 0.9515 - val_f1_score: 0.6453
# Epoch 33/50
# 286/286 [==============================] - 12s 43ms/step - loss: 0.1630 - precision: 0.9548 - recall: 0.9378 - accuracy: 0.9470 - val_loss: 3.5892 - val_precision: 0.5189 - val_recall: 0.5083 - val_accuracy: 0.5143 - f1_score: 0.9462 - val_f1_score: 0.5136
# Epoch 34/50
# 286/286 [==============================] - 12s 43ms/step - loss: 0.1519 - precision: 0.9581 - recall: 0.9413 - accuracy: 0.9486 - val_loss: 2.1833 - val_precision: 0.6269 - val_recall: 0.5805 - val_accuracy: 0.5976 - f1_score: 0.9496 - val_f1_score: 0.6028
# Epoch 35/50
# 286/286 [==============================] - 12s 42ms/step - loss: 0.1470 - precision: 0.9592 - recall: 0.9435 - accuracy: 0.9516 - val_loss: 2.4162 - val_precision: 0.6092 - val_recall: 0.5870 - val_accuracy: 0.5939 - f1_score: 0.9513 - val_f1_score: 0.5979
# Epoch 36/50
# 286/286 [==============================] - 14s 48ms/step - loss: 0.1388 - precision: 0.9614 - recall: 0.9469 - accuracy: 0.9532 - val_loss: 1.0957 - val_precision: 0.7387 - val_recall: 0.7007 - val_accuracy: 0.7202 - f1_score: 0.9540 - val_f1_score: 0.7192
# Epoch 37/50
# 286/286 [==============================] - 12s 42ms/step - loss: 0.1495 - precision: 0.9600 - recall: 0.9449 - accuracy: 0.9526 - val_loss: 3.9141 - val_precision: 0.5126 - val_recall: 0.4995 - val_accuracy: 0.5032 - f1_score: 0.9524 - val_f1_score: 0.5060
# 68/68 [==============================] - 1s 10ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87       200
#            1       0.99      0.89      0.94       200
#            2       0.98      0.79      0.87       200
#            3       0.88      0.93      0.90       200
#            4       0.99      0.96      0.97       190
#            5       0.99      0.75      0.86       198
#            6       0.99      0.76      0.86       200
#            7       0.97      0.85      0.91       175
#            8       0.86      0.98      0.92       199
#            9       0.92      0.92      0.92       200
#           10       0.52      0.98      0.68       200
#
#     accuracy                           0.87      2162
#    macro avg       0.91      0.87      0.88      2162
# weighted avg       0.91      0.87      0.88      2162
